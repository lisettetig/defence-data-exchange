# %% [markdown]
# # Text analysis and RAG for EU document analysis
#
# The following code was used to understand the role of EU's documents in either facilitating or hindering the role of data exchange in the defence sector

# %% [markdown]
# # 1. RAG
#
# For deveoping the RAG a Youtube video by Thu Vu was taken as the base code which was modified to fit the current context. https://www.youtube.com/watch?v=EFUE4DHiAPM&list=LL&index=1&t=1875s

# %%
# Import Langchain modules
from langchain.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain.vectorstores import Chroma
from langchain_core.runnables import RunnablePassthrough
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.pydantic_v1 import BaseModel, Field

# Other modules and packages
import os
import tempfile
import streamlit as st  
import pandas as pd
from dotenv import load_dotenv
from collections import defaultdict

# %%
load_dotenv()
# Out:
# True

# %%
OPENAI_API_KEY = os.environ.get("OPENAI_API_KEY")

# %% [markdown]
# ## Define the LLM

# %%
llm = ChatOpenAI(model="gpt-4o-mini", api_key=OPENAI_API_KEY)

# %% [markdown]
# ## 1.1 Process PDF documents

# %% [markdown]
# ### Load all PDF documents

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000,
                                            chunk_overlap=200,
                                            length_function=len,
                                            separators=["\n\n", "\n", " "])

# %%
# Load and split documents
all_chunks = []
chunks_by_doc = defaultdict(list)

pdf_dir = "data"
for filename in os.listdir(pdf_dir):
    if filename.lower().endswith(".pdf"):
        file_path = os.path.join(pdf_dir, filename)
        loader = PyPDFLoader(file_path)
        pages = loader.load()
        chunks = text_splitter.split_documents(pages)
        all_chunks.extend(chunks)
        chunks_by_doc[filename] = chunks

# %%
# Count total pages
total_pages = sum(len(PyPDFLoader(os.path.join(pdf_dir, f)).load()) 
                  for f in os.listdir(pdf_dir) if f.endswith(".pdf"))

# Count total chunks
total_chunks = len(all_chunks)

print(f"Total pages: {total_pages}")
print(f"Total chunks: {total_chunks}")
# Out:
# Total pages: 1818
# Total chunks: 8547

# %% [markdown]
# ### Create embeddings

# %%
def get_embedding_function():
    embeddings = OpenAIEmbeddings(
        model="text-embedding-ada-002", openai_api_key=OPENAI_API_KEY
    )
    return embeddings

embedding_function = get_embedding_function()

# %%
from langchain.evaluation import load_evaluator

evaluator = load_evaluator(evaluator="embedding_distance", 
                            embeddings=embedding_function)

# %% [markdown]
# ### Create vector database

# %%
import uuid

def create_vectorstore(chunks, embedding_function, vectorstore_path):
    
    # Create a list of unique ids for each document based on the content
    ids = [str(uuid.uuid5(uuid.NAMESPACE_DNS, doc.page_content)) for doc in chunks]
    
    # Ensure that only unique docs with unique ids are kept
    unique_ids = set()
    unique_chunks = []
    
    unique_chunks = [] 
    for chunk, id in zip(chunks, ids):     
        if id not in unique_ids:       
            unique_ids.add(id)
            unique_chunks.append(chunk) 

    # Create a new Chroma database from the documents
    vectorstore = Chroma.from_documents(documents=unique_chunks, 
                                        ids=list(unique_ids),
                                        embedding=embedding_function, 
                                        persist_directory = vectorstore_path)

    vectorstore.persist()
    
    return vectorstore

# %%
# Create vectorstore
vectorstore = create_vectorstore(chunks=chunks, 
                                 embedding_function=embedding_function, 
                                 vectorstore_path="vectorstore_chroma")

# %% [markdown]
# ## 1.2. QUERY FOR RELEVANT DATA

# %%
# Load vectorstore
vectorstore = Chroma(persist_directory="vectorstore_chroma", embedding_function=embedding_function)

# %%
print(f"Number of documents in vectorstore: {len(vectorstore.get()['documents'])}")
# Out:
# Number of documents in vectorstore: 1916

# %%
# Create retriever and get relevant chunks
retriever = vectorstore.as_retriever(search_type="similarity")
relevant_chunks = retriever.invoke("Is data exchange in defence mentioned in the document?")
relevant_chunks
# Out:
# [Document(metadata={'creationdate': '2025-03-19T11:46:08+01:00', 'creator': 'PyPDF', 'moddate': '2025-03-19T11:46:08+01:00', 'msip_label_6bd9ddd1-4d20-43f6-abfa-fc3c07406f94_actionid': '3eba1a90-0142-4259-9e27-9a4503ee2670', 'msip_label_6bd9ddd1-4d20-43f6-abfa-fc3c07406f94_contentbits': '0', 'msip_label_6bd9ddd1-4d20-43f6-abfa-fc3c07406f94_enabled': 'true', 'msip_label_6bd9ddd1-4d20-43f6-abfa-fc3c07406f94_method': 'Standard', 'msip_label_6bd9ddd1-4d20-43f6-abfa-fc3c07406f94_name': 'Commission Use', 'msip_label_6bd9ddd1-4d20-43f6-abfa-fc3c07406f94_setdate': '2025-03-17T15:45:54Z', 'msip_label_6bd9ddd1-4d20-43f6-abfa-fc3c07406f94_siteid': 'b24c8b06-522c-46fe-9080-70926f8dddb1', 'page': 20, 'page_label': '21', 'producer': 'PyPDF', 'source': 'data/29-european-defence-readiness2030.pdf', 'total_pages': 23}, page_content='20 \non the deep and extensive transatlantic supply chain, which should be mutually beneficial. The \nbilateral dialogue on Security and Defence can be enhanced to further strengthen cooperation \nin fields such as cyber, maritime security and space, discuss procurement issues and tackle any \nother matters of mutual concern. \nThe United Kingdom is an essential European ally with which cooperation on security and \ndefence should be enhanced in mutual interest, starting with a potential Security and Defence \npartnership. Building on the set of solid agreements in place, bilateral security and defenc e \ncooperation can expand, ranging from external crisis management to defence industrial \npolicies.  \nNorway is a full partner in EU defence programmes through its contribution to the EU budget. \nThe recently launched Security and Defence Partnership provides a comprehensive and \nstructured political framework for strengthening further dialogue and cooperation.'),
#  Document(metadata={'creationdate': 'D:20250326211357', 'creator': 'PDFium', 'page': 42, 'page_label': '43', 'producer': 'PDFium', 'source': 'data/edf-work-programme-2025.pdf', 'total_pages': 50}, page_content='significant effects in the area of defence \n100% \nof eligible \ncosts \nNot \napplicable \n(b) \nActivities that aim to increase interoperability and \nresilience, including secured production and exchange of \ndata, to master critical defence technologies, to strengthen \nthe security of supply or to enable the effective \nexploitation of results for defence products and \ntechnologies \n100% \nof eligible \ncosts \nUp to 65%  \nof eligible \ncosts \n(c)'),
#  Document(metadata={'creationdate': 'D:20250326211357', 'creator': 'PDFium', 'page': 24, 'page_label': '25', 'producer': 'PDFium', 'source': 'data/edf-work-programme-2025.pdf', 'total_pages': 50}, page_content='3.1.10. Air and missile defence (AIRDEF) \nThis category of actions will not be addressed under this annual work programme. \n3.1.11. Ground combat (GROUND) \nThis category of actions will be addressed through three calls for proposals in 202 5, namely \nEDF-2025-RA, EDF-2025-DA-SI and EDF-2025-DA, with four topics: \n3.1.11.1. EDF-2025-RA-GROUND-CBC: Technologies for counter-battery capabilities \nGiven that artillery is still responsible for most of the losses suffered by armies facing each'),
#  Document(metadata={'creationdate': 'D:20250326211357', 'creator': 'PDFium', 'page': 9, 'page_label': '10', 'producer': 'PDFium', 'source': 'data/edf-work-programme-2025.pdf', 'total_pages': 50}, page_content='Fields covered \n(a) (b) (c) \n1.Defence medical response, Chemical Biological Radiological Nuclear \n(CBRN), biotech and human factors X   \n2. Information superiority  X  \n3. Advanced passive and active sensors X X  \n4. Cyber  X  \n5. Space  X  \n6. Digital transformation X X  \n7. Energy resilience and environmental transition X   \n8. Materials and components X X X \n9. Air combat X  X \n10. Air and missile defence X X X \n11. Ground combat X X X \n12. Force protection and mobility X X')]

# %%
for doc in relevant_chunks:
    print(doc.page_content[:1000])  # Preview first 500 chars
# Out:
# 20
# on the deep and extensive transatlantic supply chain, which should be mutually beneficial. The
# bilateral dialogue on Security and Defence can be enhanced to further strengthen cooperation
# in fields such as cyber, maritime security and space, discuss procurement issues and tackle any
# other matters of mutual concern.
# The United Kingdom is an essential European ally with which cooperation on security and
# defence should be enhanced in mutual interest, starting with a potential Security and Defence
# partnership. Building on the set of solid agreements in place, bilateral security and defenc e
# cooperation can expand, ranging from external crisis management to defence industrial
# policies.
# Norway is a full partner in EU defence programmes through its contribution to the EU budget.
# The recently launched Security and Defence Partnership provides a comprehensive and
# structured political framework for strengthening further dialogue and cooperation.
# significant effects in the area of defence
# 100%
# of eligible
# costs
# Not
# applicable
# (b)
# Activities that aim to increase interoperability and
# resilience, including secured production and exchange of
# data, to master critical defence technologies, to strengthen
# the security of supply or to enable the effective
# exploitation of results for defence products and
# technologies
# 100%
# of eligible
# costs
# Up to 65%
# of eligible
# costs
# (c)
# 3.1.10. Air and missile defence (AIRDEF)
# This category of actions will not be addressed under this annual work programme.
# 3.1.11. Ground combat (GROUND)
# This category of actions will be addressed through three calls for proposals in 202 5, namely
# EDF-2025-RA, EDF-2025-DA-SI and EDF-2025-DA, with four topics:
# 3.1.11.1. EDF-2025-RA-GROUND-CBC: Technologies for counter-battery capabilities
# Given that artillery is still responsible for most of the losses suffered by armies facing each
# Fields covered
# (a) (b) (c)
# 1.Defence medical response, Chemical Biological Radiological Nuclear
# (CBRN), biotech and human factors X
# 2. Information superiority  X
# 3. Advanced passive and active sensors X X
# 4. Cyber  X
# 5. Space  X
# 6. Digital transformation X X
# 7. Energy resilience and environmental transition X
# 8. Materials and components X X X
# 9. Air combat X  X
# 10. Air and missile defence X X X
# 11. Ground combat X X X
# 12. Force protection and mobility X X

# %% [markdown]
# ## 1.3. Generating answers

# %%
# Prompt template
PROMPT_TEMPLATE = """
You are an assistant for structured question answering based on retrieved document context.

Given the following context, answer the question clearly, and provide:
- the direct source text used
- your reasoning for the answer

{context}

---

Respond in the following JSON structure:
{{
  "answer": "...",
  "sources": "...",
  "reasoning": "..."
}}

Question: {question}
"""

# %%
prompt_template = ChatPromptTemplate.from_template(PROMPT_TEMPLATE)

# Pydantic model for output
class AnswerWithSources(BaseModel):
    answer: str = Field(description="Answer to the question")
    sources: str = Field(description="Exact source text and location used from the context")
    reasoning: str = Field(description="Explanation of how the answer is supported by the context")

# Format context
def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)

# Questions
questions = [
    "Is the document applicable to data exchange in defence sector or is this out of scope for this document?"
]

# %%
# Run RAG pipeline per document
rows = []
for doc_name, chunks in chunks_by_doc.items():
    retriever = create_vectorstore(
        chunks, embedding_function, f"vectorstore_chroma/{doc_name}"
    ).as_retriever()

    row = {"document": doc_name}
    for i, question in enumerate(questions, 1):
        rag_chain = (
            {"context": retriever | format_docs, "question": RunnablePassthrough()}
            | prompt_template
            | llm.with_structured_output(AnswerWithSources, strict=True)
        )
        try:
            result = rag_chain.invoke(question)
            row[f"Q{i}_Answer"] = result.answer
            row[f"Q{i}_Source"] = result.sources
            row[f"Q{i}_Reasoning"] = result.reasoning
        except Exception as e:
            row[f"Q{i}_Answer"] = "Error"
            row[f"Q{i}_Source"] = ""
            row[f"Q{i}_Reasoning"] = str(e)
    rows.append(row)
# Out:
# /Users/lisette/spacyenv/lib/python3.10/site-packages/langchain_openai/chat_models/base.py:1569: UserWarning: Received a Pydantic BaseModel V1 schema. This is not supported by method="json_schema". Please use method="function_calling" or specify schema via JSON Schema or Pydantic V2 BaseModel. Overriding to method="function_calling".
#   warnings.warn(
# /Users/lisette/spacyenv/lib/python3.10/site-packages/langchain_openai/chat_models/base.py:1569: UserWarning: Received a Pydantic BaseModel V1 schema. This is not supported by method="json_schema". Please use method="function_calling" or specify schema via JSON Schema or Pydantic V2 BaseModel. Overriding to method="function_calling".
#   warnings.warn(
# /Users/lisette/spacyenv/lib/python3.10/site-packages/langchain_openai/chat_models/base.py:1569: UserWarning: Received a Pydantic BaseModel V1 schema. This is not supported by method="json_schema". Please use method="function_calling" or specify schema via JSON Schema or Pydantic V2 BaseModel. Overriding to method="function_calling".
#   warnings.warn(
# /Users/lisette/spacyenv/lib/python3.10/site-packages/langchain_openai/chat_models/base.py:1569: UserWarning: Received a Pydantic BaseModel V1 schema. This is not supported by method="json_schema". Please use method="function_calling" or specify schema via JSON Schema or Pydantic V2 BaseModel. Overriding to method="function_calling".
#   warnings.warn(
# /Users/lisette/spacyenv/lib/python3.10/site-packages/langchain_openai/chat_models/base.py:1569: UserWarning: Received a Pydantic BaseModel V1 schema. This is not supported by method="json_schema". Please use method="function_calling" or specify schema via JSON Schema or Pydantic V2 BaseModel. Overriding to method="function_calling".
#   warnings.warn(
# /Users/lisette/spacyenv/lib/python3.10/site-packages/langchain_openai/chat_models/base.py:1569: UserWarning: Received a Pydantic BaseModel V1 schema. This is not supported by method="json_schema". Please use method="function_calling" or specify schema via JSON Schema or Pydantic V2 BaseModel. Overriding to method="function_calling".
#   warnings.warn(
# /Users/lisette/spacyenv/lib/python3.10/site-packages/langchain_openai/chat_models/base.py:1569: UserWarning: Received a Pydantic BaseModel V1 schema. This is not supported by method="json_schema". Please use method="function_calling" or specify schema via JSON Schema or Pydantic V2 BaseModel. Overriding to method="function_calling".
#   warnings.warn(
# /Users/lisette/spacyenv/lib/python3.10/site-packages/langchain_openai/chat_models/base.py:1569: UserWarning: Received a Pydantic BaseModel V1 schema. This is not supported by method="json_schema". Please use method="function_calling" or specify schema via JSON Schema or Pydantic V2 BaseModel. Overriding to method="function_calling".
#   warnings.warn(
# /Users/lisette/spacyenv/lib/python3.10/site-packages/langchain_openai/chat_models/base.py:1569: UserWarning: Received a Pydantic BaseModel V1 schema. This is not supported by method="json_schema". Please use method="function_calling" or specify schema via JSON Schema or Pydantic V2 BaseModel. Overriding to method="function_calling".
#   warnings.warn(
# /Users/lisette/spacyenv/lib/python3.10/site-packages/langchain_openai/chat_models/base.py:1569: UserWarning: Received a Pydantic BaseModel V1 schema. This is not supported by method="json_schema". Please use method="function_calling" or specify schema via JSON Schema or Pydantic V2 BaseModel. Overriding to method="function_calling".
#   warnings.warn(
# /Users/lisette/spacyenv/lib/python3.10/site-packages/langchain_openai/chat_models/base.py:1569: UserWarning: Received a Pydantic BaseModel V1 schema. This is not supported by method="json_schema". Please use method="function_calling" or specify schema via JSON Schema or Pydantic V2 BaseModel. Overriding to method="function_calling".
#   warnings.warn(
# /Users/lisette/spacyenv/lib/python3.10/site-packages/langchain_openai/chat_models/base.py:1569: UserWarning: Received a Pydantic BaseModel V1 schema. This is not supported by method="json_schema". Please use method="function_calling" or specify schema via JSON Schema or Pydantic V2 BaseModel. Overriding to method="function_calling".
#   warnings.warn(
# /Users/lisette/spacyenv/lib/python3.10/site-packages/langchain_openai/chat_models/base.py:1569: UserWarning: Received a Pydantic BaseModel V1 schema. This is not supported by method="json_schema". Please use method="function_calling" or specify schema via JSON Schema or Pydantic V2 BaseModel. Overriding to method="function_calling".
#   warnings.warn(
# /Users/lisette/spacyenv/lib/python3.10/site-packages/langchain_openai/chat_models/base.py:1569: UserWarning: Received a Pydantic BaseModel V1 schema. This is not supported by method="json_schema". Please use method="function_calling" or specify schema via JSON Schema or Pydantic V2 BaseModel. Overriding to method="function_calling".
#   warnings.warn(
# /Users/lisette/spacyenv/lib/python3.10/site-packages/langchain_openai/chat_models/base.py:1569: UserWarning: Received a Pydantic BaseModel V1 schema. This is not supported by method="json_schema". Please use method="function_calling" or specify schema via JSON Schema or Pydantic V2 BaseModel. Overriding to method="function_calling".
#   warnings.warn(
# /Users/lisette/spacyenv/lib/python3.10/site-packages/langchain_openai/chat_models/base.py:1569: UserWarning: Received a Pydantic BaseModel V1 schema. This is not supported by method="json_schema". Please use method="function_calling" or specify schema via JSON Schema or Pydantic V2 BaseModel. Overriding to method="function_calling".
#   warnings.warn(
# /Users/lisette/spacyenv/lib/python3.10/site-packages/langchain_openai/chat_models/base.py:1569: UserWarning: Received a Pydantic BaseModel V1 schema. This is not supported by method="json_schema". Please use method="function_calling" or specify schema via JSON Schema or Pydantic V2 BaseModel. Overriding to method="function_calling".
#   warnings.warn(
# /Users/lisette/spacyenv/lib/python3.10/site-packages/langchain_openai/chat_models/base.py:1569: UserWarning: Received a Pydantic BaseModel V1 schema. This is not supported by method="json_schema". Please use method="function_calling" or specify schema via JSON Schema or Pydantic V2 BaseModel. Overriding to method="function_calling".
#   warnings.warn(
# /Users/lisette/spacyenv/lib/python3.10/site-packages/langchain_openai/chat_models/base.py:1569: UserWarning: Received a Pydantic BaseModel V1 schema. This is not supported by method="json_schema". Please use method="function_calling" or specify schema via JSON Schema or Pydantic V2 BaseModel. Overriding to method="function_calling".
#   warnings.warn(
# /Users/lisette/spacyenv/lib/python3.10/site-packages/langchain_openai/chat_models/base.py:1569: UserWarning: Received a Pydantic BaseModel V1 schema. This is not supported by method="json_schema". Please use method="function_calling" or specify schema via JSON Schema or Pydantic V2 BaseModel. Overriding to method="function_calling".
#   warnings.warn(
# /Users/lisette/spacyenv/lib/python3.10/site-packages/langchain_openai/chat_models/base.py:1569: UserWarning: Received a Pydantic BaseModel V1 schema. This is not supported by method="json_schema". Please use method="function_calling" or specify schema via JSON Schema or Pydantic V2 BaseModel. Overriding to method="function_calling".
#   warnings.warn(
# /Users/lisette/spacyenv/lib/python3.10/site-packages/langchain_openai/chat_models/base.py:1569: UserWarning: Received a Pydantic BaseModel V1 schema. This is not supported by method="json_schema". Please use method="function_calling" or specify schema via JSON Schema or Pydantic V2 BaseModel. Overriding to method="function_calling".
#   warnings.warn(
# /Users/lisette/spacyenv/lib/python3.10/site-packages/langchain_openai/chat_models/base.py:1569: UserWarning: Received a Pydantic BaseModel V1 schema. This is not supported by method="json_schema". Please use method="function_calling" or specify schema via JSON Schema or Pydantic V2 BaseModel. Overriding to method="function_calling".
#   warnings.warn(
# /Users/lisette/spacyenv/lib/python3.10/site-packages/langchain_openai/chat_models/base.py:1569: UserWarning: Received a Pydantic BaseModel V1 schema. This is not supported by method="json_schema". Please use method="function_calling" or specify schema via JSON Schema or Pydantic V2 BaseModel. Overriding to method="function_calling".
#   warnings.warn(
# /Users/lisette/spacyenv/lib/python3.10/site-packages/langchain_openai/chat_models/base.py:1569: UserWarning: Received a Pydantic BaseModel V1 schema. This is not supported by method="json_schema". Please use method="function_calling" or specify schema via JSON Schema or Pydantic V2 BaseModel. Overriding to method="function_calling".
#   warnings.warn(
# /Users/lisette/spacyenv/lib/python3.10/site-packages/langchain_openai/chat_models/base.py:1569: UserWarning: Received a Pydantic BaseModel V1 schema. This is not supported by method="json_schema". Please use method="function_calling" or specify schema via JSON Schema or Pydantic V2 BaseModel. Overriding to method="function_calling".
#   warnings.warn(
# /Users/lisette/spacyenv/lib/python3.10/site-packages/langchain_openai/chat_models/base.py:1569: UserWarning: Received a Pydantic BaseModel V1 schema. This is not supported by method="json_schema". Please use method="function_calling" or specify schema via JSON Schema or Pydantic V2 BaseModel. Overriding to method="function_calling".
#   warnings.warn(
# /Users/lisette/spacyenv/lib/python3.10/site-packages/langchain_openai/chat_models/base.py:1569: UserWarning: Received a Pydantic BaseModel V1 schema. This is not supported by method="json_schema". Please use method="function_calling" or specify schema via JSON Schema or Pydantic V2 BaseModel. Overriding to method="function_calling".
#   warnings.warn(
# /Users/lisette/spacyenv/lib/python3.10/site-packages/langchain_openai/chat_models/base.py:1569: UserWarning: Received a Pydantic BaseModel V1 schema. This is not supported by method="json_schema". Please use method="function_calling" or specify schema via JSON Schema or Pydantic V2 BaseModel. Overriding to method="function_calling".
#   warnings.warn(
# /Users/lisette/spacyenv/lib/python3.10/site-packages/langchain_openai/chat_models/base.py:1569: UserWarning: Received a Pydantic BaseModel V1 schema. This is not supported by method="json_schema". Please use method="function_calling" or specify schema via JSON Schema or Pydantic V2 BaseModel. Overriding to method="function_calling".
#   warnings.warn(
# /Users/lisette/spacyenv/lib/python3.10/site-packages/langchain_openai/chat_models/base.py:1569: UserWarning: Received a Pydantic BaseModel V1 schema. This is not supported by method="json_schema". Please use method="function_calling" or specify schema via JSON Schema or Pydantic V2 BaseModel. Overriding to method="function_calling".
#   warnings.warn(
# /Users/lisette/spacyenv/lib/python3.10/site-packages/langchain_openai/chat_models/base.py:1569: UserWarning: Received a Pydantic BaseModel V1 schema. This is not supported by method="json_schema". Please use method="function_calling" or specify schema via JSON Schema or Pydantic V2 BaseModel. Overriding to method="function_calling".
#   warnings.warn(
# /Users/lisette/spacyenv/lib/python3.10/site-packages/langchain_openai/chat_models/base.py:1569: UserWarning: Received a Pydantic BaseModel V1 schema. This is not supported by method="json_schema". Please use method="function_calling" or specify schema via JSON Schema or Pydantic V2 BaseModel. Overriding to method="function_calling".
#   warnings.warn(
# /Users/lisette/spacyenv/lib/python3.10/site-packages/langchain_openai/chat_models/base.py:1569: UserWarning: Received a Pydantic BaseModel V1 schema. This is not supported by method="json_schema". Please use method="function_calling" or specify schema via JSON Schema or Pydantic V2 BaseModel. Overriding to method="function_calling".
#   warnings.warn(
# /Users/lisette/spacyenv/lib/python3.10/site-packages/langchain_openai/chat_models/base.py:1569: UserWarning: Received a Pydantic BaseModel V1 schema. This is not supported by method="json_schema". Please use method="function_calling" or specify schema via JSON Schema or Pydantic V2 BaseModel. Overriding to method="function_calling".
#   warnings.warn(

# %%
# Build final table
df = pd.DataFrame(rows)
df.set_index("document", inplace=True)
df
# Out:
#                                                                                             Q1_Answer  \
# document
# 2-shaping-europes-digital-future.pdf                Yes, the document is applicable to data exchan...
# 15-EU-ideas-data-driven-economy.pdf                 The document is primarily focused on the devel...
# 23-european-single-access-point.pdf                 The document does not specifically indicate ap...
# 19-digital-decade-policy-programme-2030.pdf         The document is out of scope for data exchange...
# 7-edf-work-programme-2025.pdf                       Yes, the document is applicable to data exchan...
# 1-european-strategy-for-data.pdf                    The document is out of scope for data exchange...
# 8-edf-2025-call-topic-descriptions.pdf              Yes, the document is applicable to data exchan...
# 30-SAFE-regulation.pdf                              The document is applicable to data exchange in...
# 13-EDIRPA-implementing-decision.pdf                 The document is applicable to data exchange in...
# 17-digital-markets-act.pdf                          The document does not specifically mention app...
# 28-free-flow-of-nonpersonal-data.pdf                The document is not applicable to data exchang...
# 18-digital-europe-programme.pdf                     The document is applicable to the defence sect...
# 11EDIP.pdf                                          Yes, the document is applicable to data exchan...
# 20-chips-act.pdf                                    The document does encompass aspects relevant t...
# 27-defence-investment-gap-analysis.pdf              The document is applicable to aspects related ...
# 6-european-defence-industrial-strategy.pdf          Yes, the document is applicable to data exchan...
# 10-AI-act.pdf                                       The document indicates that it is not applicab...
# 26-ASAP-implementation-report.pdf                   The document is applicable to data exchange in...
# 31-accommodating-defence-expenditure.pdf            Yes, the document is applicable to data exchan...
# 9-edf-indicative-multiannual-perspective-2025-2...  Yes, the document is applicable to data exchan...
# 25-ASAP-communication-doc.pdf                       The document's scope is not explicitly stated ...
# 14-EDIRPA-work-programme-annex.pdf                  Yes, the document is applicable to data exchan...
# 5-gdpr.pdf                                          This document does not apply to data exchange ...
# 34-open-data-directive.pdf                          The document is out of scope for data exchange...
# 12-EDIP-staff-working-doc.PDF                       Yes, the document is applicable to data exchan...
# 24-critical-entity-resilience.pdf                   The document is applicable to data exchange in...
# 32-cyber-resilience-act.pdf                         The document is not applicable to data exchang...
# 33-interoperable-europe-act.pdf                     The document does not explicitly mention appli...
# 35-niinisto.pdf                                     The document is applicable to data exchange in...
# 4-data-act.pdf                                      The document is applicable to data exchange in...
# 16-digital-services-act.pdf                         The document does not explicitly mention that ...
# 22-cybersecurity-act.pdf                            The document does not explicitly apply to data...
# 21-NIS2-directive.pdf                               The document is applicable to data exchange in...
# 3-data-governance-act.pdf                           The document does not explicitly mention appli...
# 29-european-defence-readiness2030.pdf               The document is applicable to data exchange in...
#
#                                                                                             Q1_Source  \
# document
# 2-shaping-europes-digital-future.pdf                "building synergies between civilian cyber res...
# 15-EU-ideas-data-driven-economy.pdf                 The document discusses 'facilitating the use o...
# 23-european-single-access-point.pdf                 "validations should not relate to the content ...
# 19-digital-decade-policy-programme-2030.pdf         "it is necessary for the Union to identify sys...
# 7-edf-work-programme-2025.pdf                       Activities that aim to increase interoperabili...
# 1-european-strategy-for-data.pdf                    The context discusses data interoperability is...
# 8-edf-2025-call-topic-descriptions.pdf              Activities that aim to increase interoperabili...
# 30-SAFE-regulation.pdf                              "The proposed Regulation is an emergency measu...
# 13-EDIRPA-implementing-decision.pdf                 Those funding priorities shall aim to ensure t...
# 17-digital-markets-act.pdf                          "This Regulation respects the fundamental righ...
# 28-free-flow-of-nonpersonal-data.pdf                "This Regulation should not affect data proces...
# 18-digital-europe-programme.pdf                     "enhance cooperation between the civil and def...
# 11EDIP.pdf                                          "The mapping should be based on publicly and c...
# 20-chips-act.pdf                                    "...may be eligible to participate in all or s...
# 27-defence-investment-gap-analysis.pdf              "Measures will be considered as regards defenc...
# 6-european-defence-industrial-strategy.pdf          "This will require increased information shari...
# 10-AI-act.pdf                                       "the use of which is excluded from the scope o...
# 26-ASAP-implementation-report.pdf                   "In addition, the sensitiv ity of the subject ...
# 31-accommodating-defence-expenditure.pdf            The application of the national escape clause ...
# 9-edf-indicative-multiannual-perspective-2025-2...  ‘anonymise’ some military flights is another c...
# 25-ASAP-communication-doc.pdf                       "certification of relevant defence products wi...
# 14-EDIRPA-work-programme-annex.pdf                  "obligation to notify the Commission of contra...
# 5-gdpr.pdf                                          "This Regulation does not apply to the process...
# 34-open-data-directive.pdf                          documents, such as sensitive data, which are e...
# 12-EDIP-staff-working-doc.PDF                       "...the feasibility of a comprehensive evaluat...
# 24-critical-entity-resilience.pdf                   The scope of this Directive should apply to en...
# 32-cyber-resilience-act.pdf                         Products with digital elements that are develo...
# 33-interoperable-europe-act.pdf                     "The documentary context includes provisions f...
# 35-niinisto.pdf                                     The current CER and NIS2 directives leave out ...
# 4-data-act.pdf                                      If the addressee considers that the decision o...
# 16-digital-services-act.pdf                         "this may also warrant access to this system b...
# 22-cybersecurity-act.pdf                            Existing schemes present significant shortcomi...
# 21-NIS2-directive.pdf                               "Member States should be able to exempt specif...
# 3-data-governance-act.pdf                           "The exchange of data, purely in pursuit of th...
# 29-european-defence-readiness2030.pdf               "... procurement, intra-EU transfers of defenc...
#
#                                                                                          Q1_Reasoning
# document
# 2-shaping-europes-digital-future.pdf                The text explicitly mentions the need to build...
# 15-EU-ideas-data-driven-economy.pdf                 The explicit focus on areas such as smart grid...
# 23-european-single-access-point.pdf                 The text discusses the structures and responsi...
# 19-digital-decade-policy-programme-2030.pdf         The content of the document focuses on digital...
# 7-edf-work-programme-2025.pdf                       The context explicitly mentions activities tha...
# 1-european-strategy-for-data.pdf                    The document focuses on sectors like health an...
# 8-edf-2025-call-topic-descriptions.pdf              The context explicitly states that activities ...
# 30-SAFE-regulation.pdf                              The document explicitly discusses financial as...
# 13-EDIRPA-implementing-decision.pdf                 The context discusses funding priorities and t...
# 17-digital-markets-act.pdf                          The context discusses the general principles a...
# 28-free-flow-of-nonpersonal-data.pdf                The text clarifies that any data processing as...
# 18-digital-europe-programme.pdf                     This statement indicates that the document inc...
# 11EDIP.pdf                                          The document emphasizes the need for gathering...
# 20-chips-act.pdf                                    The document emphasizes the importance of ensu...
# 27-defence-investment-gap-analysis.pdf              The mention of cyber skills in the context of ...
# 6-european-defence-industrial-strategy.pdf          The text explicitly states the necessity for i...
# 10-AI-act.pdf                                       The text clearly states that AI systems intend...
# 26-ASAP-implementation-report.pdf                   This indicates that the document deals with se...
# 31-accommodating-defence-expenditure.pdf            The document specifically discusses the use of...
# 9-edf-indicative-multiannual-perspective-2025-2...  The document discusses critical aspects of dat...
# 25-ASAP-communication-doc.pdf                       The provided context primarily discusses produ...
# 14-EDIRPA-work-programme-annex.pdf                  The document outlines obligations related to c...
# 5-gdpr.pdf                                          The direct quote indicates that the regulation...
# 34-open-data-directive.pdf                          The context explicitly states that documents r...
# 12-EDIP-staff-working-doc.PDF                       The context speaks directly to the challenges ...
# 24-critical-entity-resilience.pdf                   The context explicitly mentions that the Direc...
# 32-cyber-resilience-act.pdf                         The explicit mention in the document that prod...
# 33-interoperable-europe-act.pdf                     The context discusses interoperability assessm...
# 35-niinisto.pdf                                     The context emphasizes the need for strengthen...
# 4-data-act.pdf                                      The text specifically addresses the protocol t...
# 16-digital-services-act.pdf                         The context emphasizes information exchange an...
# 22-cybersecurity-act.pdf                            The context discusses cybersecurity issues in ...
# 21-NIS2-directive.pdf                               The source text explicitly states that Member ...
# 3-data-governance-act.pdf                           The text outlines that the regulation is targe...
# 29-european-defence-readiness2030.pdf               The sources mention specific areas such as int...

# %%
import openpyxl
df.to_excel("defence_data_exchange_analysis2.xlsx")

# %% [markdown]
# # 2. TEXT ANALYSIS

# %%
#import necessary libraries

import fitz
import spacy
from textacy import text_stats
import pandas as pd
import os
from PyPDF2 import PdfReader
from collections import defaultdict
import re

# Load spaCy language model
nlp = spacy.load('en_core_web_sm')

# %%
# Function to extract text from PDF using PyMuPDF
def extract_text_from_pdf(pdf_path):
    doc = fitz.open(pdf_path)
    text = ""
    for page in doc:
        text += page.get_text()
    return text

# Function to get most common n-grams
def get_top_ngrams(doc, ngram_size=2, top_n=10):
    ngrams = extract.ngrams(doc, n=ngram_size, filter_stops=True, filter_punct=True, min_freq=2)
    ngram_freq = Counter([str(ngram) for ngram in ngrams])
    return ngram_freq.most_common(top_n)

# Function to extract key terms using TextRank
def extract_key_terms(doc, top_n=10):
    key_terms = extract.keyterms.textrank(doc, topn=top_n)
    return [term for term, score in key_terms]

# %%
pdf_dir = "data"
results = []

for filename in os.listdir(pdf_dir):
    if filename.lower().endswith(".pdf"):
        file_path = os.path.join(pdf_dir, filename)
        
        try:
            # Extract text
            text = extract_text_from_pdf(file_path)
            
            # Process text with spaCy
            doc = nlp(text)

            # Compute metrics
            num_sents = text_stats.basics.n_sents(doc)
            num_words = text_stats.basics.n_words(doc)
            num_unique_words = text_stats.basics.n_unique_words(doc)
            lexical_density = text_stats.diversity.ttr(doc)
            readability_score = text_stats.readability.flesch_reading_ease(doc)

            # Extract top bigrams and trigrams
            top_bigrams = get_top_ngrams(doc, ngram_size=2)
            top_trigrams = get_top_ngrams(doc, ngram_size=3)

            # Extract key terms
            key_terms = extract_key_terms(doc)

            # Append results
            results.append({
                'Filename': filename,
                'Number of Sentences': num_sents,
                'Number of Words': num_words,
                'Number of Unique Words': num_unique_words,
                'Lexical Density (TTR)': lexical_density,
                'Flesch Reading Ease Score': readability_score,
                'Top 10 Bigrams': top_bigrams,
                'Top 10 Trigrams': top_trigrams,
                'Top 10 Key Terms': key_terms
            })

            print(f"Processed: {filename}")

        except Exception as e:
            print(f"Error processing {filename}: {e}")

# Create DataFrame and export to Excel
df = pd.DataFrame(results)
df.to_excel("output.xlsx", index=False)

print("All documents processed. Results saved to 'output.xlsx'.")
# Out:
# Processed: 2-shaping-europes-digital-future.pdf
# Processed: 15-EU-ideas-data-driven-economy.pdf
# Processed: 23-european-single-access-point.pdf
# Processed: 19-digital-decade-policy-programme-2030.pdf
# Processed: 7-edf-work-programme-2025.pdf
# Processed: 1-european-strategy-for-data.pdf
# Processed: 8-edf-2025-call-topic-descriptions.pdf
# Processed: 30-SAFE-regulation.pdf
# Processed: 13-EDIRPA-implementing-decision.pdf
# Processed: 17-digital-markets-act.pdf
# Processed: 28-free-flow-of-nonpersonal-data.pdf
# Processed: 18-digital-europe-programme.pdf
# Processed: 11EDIP.pdf
# Processed: 20-chips-act.pdf
# Processed: 27-defence-investment-gap-analysis.pdf
# Processed: 6-european-defence-industrial-strategy.pdf
# Processed: 10-AI-act.pdf
# Processed: 26-ASAP-implementation-report.pdf
# Processed: 31-accommodating-defence-expenditure.pdf
# Processed: 9-edf-indicative-multiannual-perspective-2025-2027.pdf
# Processed: 25-ASAP-communication-doc.pdf
# Processed: 14-EDIRPA-work-programme-annex.pdf
# Processed: 5-gdpr.pdf
# Processed: 34-open-data-directive.pdf
# Processed: 12-EDIP-staff-working-doc.PDF
# Processed: 24-critical-entity-resilience.pdf
# Processed: 32-cyber-resilience-act.pdf
# Processed: 33-interoperable-europe-act.pdf
# Processed: 35-niinisto.pdf
# Processed: 4-data-act.pdf
# Processed: 16-digital-services-act.pdf
# Processed: 22-cybersecurity-act.pdf
# Processed: 21-NIS2-directive.pdf
# Processed: 3-data-governance-act.pdf
# Processed: 29-european-defence-readiness2030.pdf
# All documents processed. Results saved to 'output.xlsx'.

# %% [markdown]
# ### Keywords

# %%
# Canonical keyword groups with data exchange in defence-specific terms
keyword_map = {
    "defence": ["defence", "defense"],
    "military": ["military", "armed forces"],
    "security": ["security", "secure", "securing"],
    "data exchange": ["data exchange", "information exchange"],
    "data sharing": ["data sharing", "information sharing"],
    "interoperability": ["interoperability", "inter-operability", "interoperable"],
    "sovereignty": ["sovereignty", "sovereign"],
    "trust": ["trust", "trusted", "trustworthy"],
    "privacy": ["privacy", "private", "confidentiality"],
    "data exchange in defence": [
        "military data exchange", "defence data exchange", "interoperability of defence systems",
        "defence data sharing", "military interoperability", "secure communication systems",
        "tactical data link", "coalition data exchange", "battlefield information sharing",
        "command and control interoperability", "defence information sharing", "military information sharing",
        "defence information exchange"
    ]
}

# Context-based exclusion for "private"
exclude_if_near = {"sector", "company", "organisation", "organization", "entity", "enterprise", "partner"}

results = []

for filename in os.listdir("data"):
    if filename.endswith(".pdf"):
        reader = PdfReader(os.path.join("data", filename))
        full_text = "\n".join([page.extract_text() or "" for page in reader.pages]).lower()

        # Process with spaCy
        doc = nlp(full_text)
        lemmatized_tokens = [token.lemma_ for token in doc if token.is_alpha]
        text_for_phrases = doc.text.lower()

        doc_result = {"document": filename}

        for canon, variants in keyword_map.items():
            if canon == "privacy":
                # Special handling for "private"
                privacy_count = 0
                for i, token in enumerate(doc):
                    if token.lemma_ == "private":
                        context = doc[max(0, i - 3): i + 4]
                        context_words = {tok.lemma_ for tok in context}
                        if not context_words & exclude_if_near:
                            privacy_count += 1

                # Add additional phrases like "privacy", "confidentiality"
                phrase_matches = sum(
                    len(re.findall(re.escape(phrase), text_for_phrases))
                    for phrase in variants if phrase != "private"
                )

                total = privacy_count + phrase_matches
                doc_result[canon] = total

            else:
                # Count lemmatized token matches
                token_matches = sum(1 for lemma in lemmatized_tokens if lemma in variants)
                # Count phrase matches
                phrase_matches = sum(
                    len(re.findall(re.escape(phrase), text_for_phrases))
                    for phrase in variants if " " in phrase
                )
                total = token_matches + phrase_matches
                doc_result[canon] = total

        results.append(doc_result)

# Output as DataFrame
df_fuzzy_keywords = pd.DataFrame(results)
df_fuzzy_keywords.set_index("document", inplace=True)
df_fuzzy_keywords
# Out:
#                                                     defence  military  \
# document
# 2-shaping-europes-digital-future.pdf                      0         0
# 15-EU-ideas-data-driven-economy.pdf                       0         0
# 23-european-single-access-point.pdf                       0         0
# 19-digital-decade-policy-programme-2030.pdf               2         0
# 7-edf-work-programme-2025.pdf                           188        28
# 1-european-strategy-for-data.pdf                          0         0
# 8-edf-2025-call-topic-descriptions.pdf                  459       127
# 30-SAFE-regulation.pdf                                  198        13
# 13-EDIRPA-implementing-decision.pdf                       5         0
# 17-digital-markets-act.pdf                                1         0
# 28-free-flow-of-nonpersonal-data.pdf                      0         0
# 18-digital-europe-programme.pdf                           1         0
# 11EDIP.pdf                                              469        22
# 20-chips-act.pdf                                          4         0
# 27-defence-investment-gap-analysis.pdf                  180        24
# 6-european-defence-industrial-strategy.pdf              312        39
# 10-AI-act.pdf                                            17        11
# 26-ASAP-implementation-report.pdf                        45         1
# 31-accommodating-defence-expenditure.pdf                 63         9
# 9-edf-indicative-multiannual-perspective-2025-2...      216       128
# 25-ASAP-communication-doc.pdf                            18         0
# 14-EDIRPA-work-programme-annex.pdf                       46         1
# 5-gdpr.pdf                                               10         0
# 34-open-data-directive.pdf                                2         0
# 24-critical-entity-resilience.pdf                        10         0
# 32-cyber-resilience-act.pdf                               2         0
# 33-interoperable-europe-act.pdf                           1         0
# 35-niinisto.pdf                                         394       396
# 4-data-act.pdf                                            5         0
# 16-digital-services-act.pdf                               4         0
# 22-cybersecurity-act.pdf                                  4         0
# 21-NIS2-directive.pdf                                    13         0
# 3-data-governance-act.pdf                                 6         0
# 29-european-defence-readiness2030.pdf                   242        71
#
#                                                     security  data exchange  \
# document
# 2-shaping-europes-digital-future.pdf                      14              0
# 15-EU-ideas-data-driven-economy.pdf                       17              1
# 23-european-single-access-point.pdf                       10              0
# 19-digital-decade-policy-programme-2030.pdf               19              0
